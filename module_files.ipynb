# %%
filename = "mods.txt"

with open(filename, 'r') as infile:
    for line in infile:
        if line.startswith('------'):
            line = line.strip('-').strip().rstrip('-').rstrip()
            #print (line)
            module_type = line.rsplit('/',1)[1]
            
            #print (module_type)
        else:
            line = line.split()
            for count in range (0, len(line)):
                module = line[count].split('/')         
                module.insert (0, module_type)
                    
                print (module)
# Out:
# ['infrastructure', 'allinea', '4.2.2-39422']
# ['infrastructure', 'lmutil', '11.12.1.0v6']
# ['infrastructure', 'ant', '1.8.0']
# ['infrastructure', 'maven', '3.0.3']
# ['infrastructure', 'autoconf', '2.68']
# ['infrastructure', 'mercurial', '1.9.2']
# ['infrastructure', 'automake', '1.13.2']
# ['infrastructure', 'mercurial', '3.7.2']
# ['infrastructure', 'bit', '32']
# ['infrastructure', 'mpe2', '1.3.0']
# ['infrastructure', 'bit', '64']
# ['infrastructure', 'mvapich', '1.2rc1']
# ['infrastructure', 'charm', '6.2.2-namd']
# ['infrastructure', 'mvapich2', '1.4(default)']
# ['infrastructure', 'charm', '6.3.2-namd']
# ['infrastructure', 'nvidia', '280.13']
# ['infrastructure', 'cmake', '2.8.11.2']
# ['infrastructure', 'openmpi', '1.2.9']
# ['infrastructure', 'cmake', '2.8.2']
# ['infrastructure', 'openmpi', '1.4(default)']
# ['infrastructure', 'cmake', '3.2.3']
# ['infrastructure', 'openmpi', '1.5.3']
# ['infrastructure', 'darcs', '2.5.2']
# ['infrastructure', 'openmpi', '1.6.5']
# ['infrastructure', 'doxygen', '1.8.8']
# ['infrastructure', 'sge']
# ['infrastructure', 'flex', '2.5.39']
# ['infrastructure', 'sgedev']
# ['infrastructure', 'git', '1.7.3.1']
# ['infrastructure', 'srb', '3.3.1']
# ['infrastructure', 'globus', '5.0.4']
# ['infrastructure', 'subversion', '1.6.15(default)']
# ['infrastructure', 'intelmpi', '4.1.0.024(default)']
# ['infrastructure', 'subversion', '1.6.9']
# ['infrastructure', 'intelmpi', '4.1.1.036']
# ['infrastructure', 'system']
# ['infrastructure', 'intelmpi', '5.1.0.038']
# ['infrastructure', 'test']
# ['infrastructure', 'libtool', '2.4.2']
# ['infrastructure', 'user']
# ['infrastructure', 'licenses']
# ['compilers', 'epd', '7.3-1']
# ['compilers', 'intel', '15.0.0']
# ['compilers', 'pgi', '13.6']
# ['compilers', 'gnu', '4.2.3']
# ['compilers', 'intel', '16.0.2']
# ['compilers', 'python', '2.6.5']
# ['compilers', 'gnu', '4.4.5']
# ['compilers', 'intel', '2011.2.137']
# ['compilers', 'python', '2.7.2']
# ['compilers', 'gnu', '4.7.1']
# ['compilers', 'java', '1.6.0_17']
# ['compilers', 'python', '2.7.6']
# ['compilers', 'gnu', '4.8.1']
# ['compilers', 'java', '7u45']
# ['compilers', 'python', '3.1.2(default)']
# ['compilers', 'gnu', '5.3.0']
# ['compilers', 'mono', '2.8.1']
# ['compilers', 'python', '3.3.6']
# ['compilers', 'gnu', 'native(default)']
# ['compilers', 'perl', 'native']
# ['compilers', 'python', 'native']
# ['compilers', 'intel', '11.1.059(default)']
# ['compilers', 'pgi', '10.0(default)']
# ['compilers', 'tcl', '8.3.5']
# ['compilers', 'intel', '13.1.3.192']
# ['compilers', 'pgi', '11.3']
# ['compilers', 'yasm', '1.2.0']
# ['libraries', 'acml', '4.4.0']
# ['libraries', 'mkl', '11.0u5']
# ['libraries', 'antlr', '2.7.7']
# ['libraries', 'mkl', '11.2']
# ['libraries', 'armadillo', '3.810.2']
# ['libraries', 'netcdf', '3.6.3(default)']
# ['libraries', 'atlas', '3.10.1']
# ['libraries', 'netcdf', '4.3.0']
# ['libraries', 'atlas', '3.8.3']
# ['libraries', 'netlib', '3.3.0']
# ['libraries', 'boost', '1.53.0']
# ['libraries', 'ompP', '0.8.5']
# ['libraries', 'cube', '4.2.3']
# ['libraries', 'opencv', '2.2.0']
# ['libraries', 'cube', '4.3.1']
# ['libraries', 'opencv', '2.4.6.1']
# ['libraries', 'darshan', '2.3.0']
# ['libraries', 'openjpeg', '1.5.1']
# ['libraries', 'eigen', '3.2.2']
# ['libraries', 'openslide', '3.2.6']
# ['libraries', 'ffmpeg', '0.6.2']
# ['libraries', 'otf2', '1.2.1']
# ['libraries', 'ffmpeg', '1.2']
# ['libraries', 'otf2', '1.5.1']
# ['libraries', 'ffmpeg', '2.0.2']
# ['libraries', 'papi', '5.4.0']
# ['libraries', 'fftw', '2.1.5']
# ['libraries', 'pdt', '3.20']
# ['libraries', 'fftw', '3.2.2']
# ['libraries', 'perl-libs', '1.0.0']
# ['libraries', 'fftw', '3.3.3']
# ['libraries', 'petsc', '3.1-p8']
# ['libraries', 'freetype', '2.4.12']
# ['libraries', 'pgplot', '5.2.2']
# ['libraries', 'gdal', '1.11.0']
# ['libraries', 'proj', '4.8.0']
# ['libraries', 'geos', '3.4.2']
# ['libraries', 'python-libs', '1.0.0']
# ['libraries', 'graphviz', '2.28.0']
# ['libraries', 'python-libs', '1.0.1(default)']
# ['libraries', 'gsl', '1.14']
# ['libraries', 'python-libs', '1.0.2']
# ['libraries', 'gsl', '1.15']
# ['libraries', 'python-libs', '1.0.3']
# ['libraries', 'harminv', '1.3.1']
# ['libraries', 'python-libs', '2.4.0']
# ['libraries', 'hdf-java', '2.9']
# ['libraries', 'qt', '4.8.6']
# ['libraries', 'hdf5', '1.8.11']
# ['libraries', 'root', '5.34.05']
# ['libraries', 'hdf5', '1.8.12']
# ['libraries', 'root', '5.34.23']
# ['libraries', 'hdf5', '1.8.5p1(default)']
# ['libraries', 'scorep', '1.3']
# ['libraries', 'hypre', '2.7.0b']
# ['libraries', 'scorep', '1.4.1']
# ['libraries', 'hypre', '2.9.0b']
# ['libraries', 'silo', '4.10.2']
# ['libraries', 'itac', '8.0.3.007']
# ['libraries', 'suitesparse', '3.6.0']
# ['libraries', 'jasper', '1.900.1']
# ['libraries', 'suitesparse', '4.2.1']
# ['libraries', 'libctl', '3.1']
# ['libraries', 'tau', '2.24']
# ['libraries', 'libunwind', '1.1']
# ['libraries', 'udunits', '2.2.17']
# ['libraries', 'lzo', '2.04']
# ['libraries', 'vtk', '5.6.1']
# ['libraries', 'mkl', '10.3u2(default)']
# ['libraries', 'wxgtk', '2.8.11']
# ['applications', 'FusionMap', '1.42']
# ['applications', 'comsol', '4.1']
# ['applications', 'matlab', 'R2012a']
# ['applications', 'R', '2.10.1']
# ['applications', 'comsol', '4.2']
# ['applications', 'meep', '1.1.1']
# ['applications', 'R', '2.13.0']
# ['applications', 'comsol', '4.2a']
# ['applications', 'mesmer', '4.0']
# ['applications', 'R', '2.15.0']
# ['applications', 'comsol', '4.3']
# ['applications', 'molpro', '2006.1.148']
# ['applications', 'R', '2.15.3']
# ['applications', 'comsol', '4.3a']
# ['applications', 'molpro', '2010.1.23(default)']
# ['applications', 'R', '3.0.2']
# ['applications', 'comsol', '4.3b']
# ['applications', 'molpro', '2010.1.24']
# ['applications', 'R', '3.1.0']
# ['applications', 'cufflinks', '1.3.0']
# ['applications', 'mpb', '1.4.2']
# ['applications', 'R', '3.2.0']
# ['applications', 'cufflinks', '2.2.1']
# ['applications', 'namd', '2.7b4']
# ['applications', 'R', '3.2.2']
# ['applications', 'desmond', '2.2.9.1']
# ['applications', 'namd', '2.8']
# ['applications', 'abaqus', '6.10']
# ['applications', 'dl_poly', '2.20']
# ['applications', 'namd', '2.9']
# ['applications', 'abaqus', '6.12']
# ['applications', 'dl_poly', '4.05']
# ['applications', 'nbo', '6']
# ['applications', 'abaqus', '6.9EF']
# ['applications', 'ehits', '12.0(default)']
# ['applications', 'ncl', '6.0.0-beta']
# ['applications', 'adams', '2013.2']
# ['applications', 'ehits', '13.0']
# ['applications', 'nco', '4.0.8(default)']
# ['applications', 'aimpro', '2.3.11b2']
# ['applications', 'ehits', '14.0.3']
# ['applications', 'nco', '4.3.7']
# ['applications', 'amber', '10(default)']
# ['applications', 'ehits', '2009.1']
# ['applications', 'ncview', '1.93g']
# ['applications', 'amber', '12']
# ['applications', 'espresso', '4.1.2']
# ['applications', 'onetep', '3.0.0']
# ['applications', 'amber', '9']
# ['applications', 'ferret', '6.8.5']
# ['applications', 'opendx', '4.4.4']
# ['applications', 'ansys', '12.0']
# ['applications', 'gaussian', 'G03.D02']
# ['applications', 'openeye', '3.0.1']
# ['applications', 'ansys', '12.1']
# ['applications', 'gaussian', 'G09']
# ['applications', 'openfoam', '1.7.1']
# ['applications', 'ansys', '13.0']
# ['applications', 'gaussian', 'G09.D01']
# ['applications', 'openfoam', '2.1.1']
# ['applications', 'ansys', '13.0sp2']
# ['applications', 'gmt', '4.5.2']
# ['applications', 'paraview', '3.8.1']
# ['applications', 'ansys', '14.0']
# ['applications', 'gnuplot', '4.2.3']
# ['applications', 'pari', '2.5.0']
# ['applications', 'ansys', '14.5.7']
# ['applications', 'grace', '5.1.22']
# ['applications', 'relion', '1.2']
# ['applications', 'ansys', '16.2']
# ['applications', 'gromacs', '4.5.1']
# ['applications', 'samtools', '0.1.18']
# ['applications', 'ansysem', '15.0']
# ['applications', 'gromacs', '4.5.3']
# ['applications', 'sas', '9.2.2']
# ['applications', 'aten', '1.3']
# ['applications', 'gromacs', '4.5.5']
# ['applications', 'schrodinger', '2014-3']
# ['applications', 'bfast', '0.7.0a']
# ['applications', 'gromacs', '4.6.3']
# ['applications', 'schrodinger', '2016-3']
# ['applications', 'blast', '2.2.25']
# ['applications', 'gulp', '3.4']
# ['applications', 'stata', '12']
# ['applications', 'bowtie', '0.12.7']
# ['applications', 'h5utils', '1.12.1']
# ['applications', 'stata', '13']
# ['applications', 'bwa', '0.6.1']
# ['applications', 'hyperworks', '10(default)']
# ['applications', 'stata', '13.1']
# ['applications', 'bwa', '0.7.6a']
# ['applications', 'idl', '7.0']
# ['applications', 'tophat', '1.3.3']
# ['applications', 'castep', '4.4.6']
# ['applications', 'iris-explorer', '5.2']
# ['applications', 'visit', '2.9.2']
# ['applications', 'castep', '5.0.1']
# ['applications', 'joint-snv-mix', '0.7.3']
# ['applications', 'vmd', '1.8.7']
# ['applications', 'castep', '5.0.2']
# ['applications', 'ls-dyna', '971r4.2.1']
# ['applications', 'weka', '3.6.7']
# ['applications', 'castep', '5.5']
# ['applications', 'macs', '1.3.7']
# ['applications', 'wien2k', '09.2']
# ['applications', 'castep', '5.5.1']
# ['applications', 'macs', '1.4.1']
# ['applications', 'wien2k', '11.1']
# ['applications', 'castep', '6.0p3(default)']
# ['applications', 'materialsstudio', '5.5.3']
# ['applications', 'xmipp', '2.4']
# ['applications', 'castep', '6.1.1']
# ['applications', 'matlab', '7.9(default)']
# ['privatemodules', 'conda', '2']
# ['privatemodules', 'conda', '3']

# %%
filename = "mods.txt"

with open(filename, 'r') as infile:
    for line in infile:
        if line.startswith('------'):
            line = line.strip('-').strip().rstrip('-').rstrip()
            #print (line)
            module_type = line.rsplit('/',1)[1]
            
            #print (module_type)
        elif module_type != 'privatemodules':
            line = line.split()
            for count in range (0, len(line)):
                module = line[count].split('/')         
                module.insert (0, module_type)
                    
                print (module)
# Out:
# ['infrastructure', 'allinea', '4.2.2-39422']
# ['infrastructure', 'lmutil', '11.12.1.0v6']
# ['infrastructure', 'ant', '1.8.0']
# ['infrastructure', 'maven', '3.0.3']
# ['infrastructure', 'autoconf', '2.68']
# ['infrastructure', 'mercurial', '1.9.2']
# ['infrastructure', 'automake', '1.13.2']
# ['infrastructure', 'mercurial', '3.7.2']
# ['infrastructure', 'bit', '32']
# ['infrastructure', 'mpe2', '1.3.0']
# ['infrastructure', 'bit', '64']
# ['infrastructure', 'mvapich', '1.2rc1']
# ['infrastructure', 'charm', '6.2.2-namd']
# ['infrastructure', 'mvapich2', '1.4(default)']
# ['infrastructure', 'charm', '6.3.2-namd']
# ['infrastructure', 'nvidia', '280.13']
# ['infrastructure', 'cmake', '2.8.11.2']
# ['infrastructure', 'openmpi', '1.2.9']
# ['infrastructure', 'cmake', '2.8.2']
# ['infrastructure', 'openmpi', '1.4(default)']
# ['infrastructure', 'cmake', '3.2.3']
# ['infrastructure', 'openmpi', '1.5.3']
# ['infrastructure', 'darcs', '2.5.2']
# ['infrastructure', 'openmpi', '1.6.5']
# ['infrastructure', 'doxygen', '1.8.8']
# ['infrastructure', 'sge']
# ['infrastructure', 'flex', '2.5.39']
# ['infrastructure', 'sgedev']
# ['infrastructure', 'git', '1.7.3.1']
# ['infrastructure', 'srb', '3.3.1']
# ['infrastructure', 'globus', '5.0.4']
# ['infrastructure', 'subversion', '1.6.15(default)']
# ['infrastructure', 'intelmpi', '4.1.0.024(default)']
# ['infrastructure', 'subversion', '1.6.9']
# ['infrastructure', 'intelmpi', '4.1.1.036']
# ['infrastructure', 'system']
# ['infrastructure', 'intelmpi', '5.1.0.038']
# ['infrastructure', 'test']
# ['infrastructure', 'libtool', '2.4.2']
# ['infrastructure', 'user']
# ['infrastructure', 'licenses']
# ['compilers', 'epd', '7.3-1']
# ['compilers', 'intel', '15.0.0']
# ['compilers', 'pgi', '13.6']
# ['compilers', 'gnu', '4.2.3']
# ['compilers', 'intel', '16.0.2']
# ['compilers', 'python', '2.6.5']
# ['compilers', 'gnu', '4.4.5']
# ['compilers', 'intel', '2011.2.137']
# ['compilers', 'python', '2.7.2']
# ['compilers', 'gnu', '4.7.1']
# ['compilers', 'java', '1.6.0_17']
# ['compilers', 'python', '2.7.6']
# ['compilers', 'gnu', '4.8.1']
# ['compilers', 'java', '7u45']
# ['compilers', 'python', '3.1.2(default)']
# ['compilers', 'gnu', '5.3.0']
# ['compilers', 'mono', '2.8.1']
# ['compilers', 'python', '3.3.6']
# ['compilers', 'gnu', 'native(default)']
# ['compilers', 'perl', 'native']
# ['compilers', 'python', 'native']
# ['compilers', 'intel', '11.1.059(default)']
# ['compilers', 'pgi', '10.0(default)']
# ['compilers', 'tcl', '8.3.5']
# ['compilers', 'intel', '13.1.3.192']
# ['compilers', 'pgi', '11.3']
# ['compilers', 'yasm', '1.2.0']
# ['libraries', 'acml', '4.4.0']
# ['libraries', 'mkl', '11.0u5']
# ['libraries', 'antlr', '2.7.7']
# ['libraries', 'mkl', '11.2']
# ['libraries', 'armadillo', '3.810.2']
# ['libraries', 'netcdf', '3.6.3(default)']
# ['libraries', 'atlas', '3.10.1']
# ['libraries', 'netcdf', '4.3.0']
# ['libraries', 'atlas', '3.8.3']
# ['libraries', 'netlib', '3.3.0']
# ['libraries', 'boost', '1.53.0']
# ['libraries', 'ompP', '0.8.5']
# ['libraries', 'cube', '4.2.3']
# ['libraries', 'opencv', '2.2.0']
# ['libraries', 'cube', '4.3.1']
# ['libraries', 'opencv', '2.4.6.1']
# ['libraries', 'darshan', '2.3.0']
# ['libraries', 'openjpeg', '1.5.1']
# ['libraries', 'eigen', '3.2.2']
# ['libraries', 'openslide', '3.2.6']
# ['libraries', 'ffmpeg', '0.6.2']
# ['libraries', 'otf2', '1.2.1']
# ['libraries', 'ffmpeg', '1.2']
# ['libraries', 'otf2', '1.5.1']
# ['libraries', 'ffmpeg', '2.0.2']
# ['libraries', 'papi', '5.4.0']
# ['libraries', 'fftw', '2.1.5']
# ['libraries', 'pdt', '3.20']
# ['libraries', 'fftw', '3.2.2']
# ['libraries', 'perl-libs', '1.0.0']
# ['libraries', 'fftw', '3.3.3']
# ['libraries', 'petsc', '3.1-p8']
# ['libraries', 'freetype', '2.4.12']
# ['libraries', 'pgplot', '5.2.2']
# ['libraries', 'gdal', '1.11.0']
# ['libraries', 'proj', '4.8.0']
# ['libraries', 'geos', '3.4.2']
# ['libraries', 'python-libs', '1.0.0']
# ['libraries', 'graphviz', '2.28.0']
# ['libraries', 'python-libs', '1.0.1(default)']
# ['libraries', 'gsl', '1.14']
# ['libraries', 'python-libs', '1.0.2']
# ['libraries', 'gsl', '1.15']
# ['libraries', 'python-libs', '1.0.3']
# ['libraries', 'harminv', '1.3.1']
# ['libraries', 'python-libs', '2.4.0']
# ['libraries', 'hdf-java', '2.9']
# ['libraries', 'qt', '4.8.6']
# ['libraries', 'hdf5', '1.8.11']
# ['libraries', 'root', '5.34.05']
# ['libraries', 'hdf5', '1.8.12']
# ['libraries', 'root', '5.34.23']
# ['libraries', 'hdf5', '1.8.5p1(default)']
# ['libraries', 'scorep', '1.3']
# ['libraries', 'hypre', '2.7.0b']
# ['libraries', 'scorep', '1.4.1']
# ['libraries', 'hypre', '2.9.0b']
# ['libraries', 'silo', '4.10.2']
# ['libraries', 'itac', '8.0.3.007']
# ['libraries', 'suitesparse', '3.6.0']
# ['libraries', 'jasper', '1.900.1']
# ['libraries', 'suitesparse', '4.2.1']
# ['libraries', 'libctl', '3.1']
# ['libraries', 'tau', '2.24']
# ['libraries', 'libunwind', '1.1']
# ['libraries', 'udunits', '2.2.17']
# ['libraries', 'lzo', '2.04']
# ['libraries', 'vtk', '5.6.1']
# ['libraries', 'mkl', '10.3u2(default)']
# ['libraries', 'wxgtk', '2.8.11']
# ['applications', 'FusionMap', '1.42']
# ['applications', 'comsol', '4.1']
# ['applications', 'matlab', 'R2012a']
# ['applications', 'R', '2.10.1']
# ['applications', 'comsol', '4.2']
# ['applications', 'meep', '1.1.1']
# ['applications', 'R', '2.13.0']
# ['applications', 'comsol', '4.2a']
# ['applications', 'mesmer', '4.0']
# ['applications', 'R', '2.15.0']
# ['applications', 'comsol', '4.3']
# ['applications', 'molpro', '2006.1.148']
# ['applications', 'R', '2.15.3']
# ['applications', 'comsol', '4.3a']
# ['applications', 'molpro', '2010.1.23(default)']
# ['applications', 'R', '3.0.2']
# ['applications', 'comsol', '4.3b']
# ['applications', 'molpro', '2010.1.24']
# ['applications', 'R', '3.1.0']
# ['applications', 'cufflinks', '1.3.0']
# ['applications', 'mpb', '1.4.2']
# ['applications', 'R', '3.2.0']
# ['applications', 'cufflinks', '2.2.1']
# ['applications', 'namd', '2.7b4']
# ['applications', 'R', '3.2.2']
# ['applications', 'desmond', '2.2.9.1']
# ['applications', 'namd', '2.8']
# ['applications', 'abaqus', '6.10']
# ['applications', 'dl_poly', '2.20']
# ['applications', 'namd', '2.9']
# ['applications', 'abaqus', '6.12']
# ['applications', 'dl_poly', '4.05']
# ['applications', 'nbo', '6']
# ['applications', 'abaqus', '6.9EF']
# ['applications', 'ehits', '12.0(default)']
# ['applications', 'ncl', '6.0.0-beta']
# ['applications', 'adams', '2013.2']
# ['applications', 'ehits', '13.0']
# ['applications', 'nco', '4.0.8(default)']
# ['applications', 'aimpro', '2.3.11b2']
# ['applications', 'ehits', '14.0.3']
# ['applications', 'nco', '4.3.7']
# ['applications', 'amber', '10(default)']
# ['applications', 'ehits', '2009.1']
# ['applications', 'ncview', '1.93g']
# ['applications', 'amber', '12']
# ['applications', 'espresso', '4.1.2']
# ['applications', 'onetep', '3.0.0']
# ['applications', 'amber', '9']
# ['applications', 'ferret', '6.8.5']
# ['applications', 'opendx', '4.4.4']
# ['applications', 'ansys', '12.0']
# ['applications', 'gaussian', 'G03.D02']
# ['applications', 'openeye', '3.0.1']
# ['applications', 'ansys', '12.1']
# ['applications', 'gaussian', 'G09']
# ['applications', 'openfoam', '1.7.1']
# ['applications', 'ansys', '13.0']
# ['applications', 'gaussian', 'G09.D01']
# ['applications', 'openfoam', '2.1.1']
# ['applications', 'ansys', '13.0sp2']
# ['applications', 'gmt', '4.5.2']
# ['applications', 'paraview', '3.8.1']
# ['applications', 'ansys', '14.0']
# ['applications', 'gnuplot', '4.2.3']
# ['applications', 'pari', '2.5.0']
# ['applications', 'ansys', '14.5.7']
# ['applications', 'grace', '5.1.22']
# ['applications', 'relion', '1.2']
# ['applications', 'ansys', '16.2']
# ['applications', 'gromacs', '4.5.1']
# ['applications', 'samtools', '0.1.18']
# ['applications', 'ansysem', '15.0']
# ['applications', 'gromacs', '4.5.3']
# ['applications', 'sas', '9.2.2']
# ['applications', 'aten', '1.3']
# ['applications', 'gromacs', '4.5.5']
# ['applications', 'schrodinger', '2014-3']
# ['applications', 'bfast', '0.7.0a']
# ['applications', 'gromacs', '4.6.3']
# ['applications', 'schrodinger', '2016-3']
# ['applications', 'blast', '2.2.25']
# ['applications', 'gulp', '3.4']
# ['applications', 'stata', '12']
# ['applications', 'bowtie', '0.12.7']
# ['applications', 'h5utils', '1.12.1']
# ['applications', 'stata', '13']
# ['applications', 'bwa', '0.6.1']
# ['applications', 'hyperworks', '10(default)']
# ['applications', 'stata', '13.1']
# ['applications', 'bwa', '0.7.6a']
# ['applications', 'idl', '7.0']
# ['applications', 'tophat', '1.3.3']
# ['applications', 'castep', '4.4.6']
# ['applications', 'iris-explorer', '5.2']
# ['applications', 'visit', '2.9.2']
# ['applications', 'castep', '5.0.1']
# ['applications', 'joint-snv-mix', '0.7.3']
# ['applications', 'vmd', '1.8.7']
# ['applications', 'castep', '5.0.2']
# ['applications', 'ls-dyna', '971r4.2.1']
# ['applications', 'weka', '3.6.7']
# ['applications', 'castep', '5.5']
# ['applications', 'macs', '1.3.7']
# ['applications', 'wien2k', '09.2']
# ['applications', 'castep', '5.5.1']
# ['applications', 'macs', '1.4.1']
# ['applications', 'wien2k', '11.1']
# ['applications', 'castep', '6.0p3(default)']
# ['applications', 'materialsstudio', '5.5.3']
# ['applications', 'xmipp', '2.4']
# ['applications', 'castep', '6.1.1']
# ['applications', 'matlab', '7.9(default)']

# %%
import sqlite3

# %%
filename = 'mods.sqlite'
conn = sqlite3.connect(filename)
c = conn.cursor()

# %%
c.execute("INSERT OR IGNORE INTO service(servicename) VALUES ('arc1')")

# %%
conn.commit()
conn.close()

# %%
filename = "mods.txt"
servicename = 'arc1'

dbfilename = 'mods.sqlite'
conn = sqlite3.connect(dbfilename)
c = conn.cursor()

with open(filename, 'r') as infile:
    for line in infile:
        if line.startswith('------'):
            line = line.strip('-').strip().rstrip('-').rstrip()
            #print (line)
            module_type = line.rsplit('/',1)[1]
            
            #print (module_type)
        elif module_type != 'privatemodules':
            line = line.split()
            for count in range (0, len(line)):
                module = line[count].split('/')         
                module.insert (0, module_type)
                module.insert (0, servicename)
                    
                print (module)
                modulename = module[2]
                module_type = module[1]
                print (module_type)
                
                try:
                    moduleversion = module[3]
                except IndexError:
                    moduleversion = ''
                
                c.execute("INSERT OR IGNORE INTO service(servicename) VALUES ('" + servicename + "')")
                sql = "INSERT OR IGNORE INTO module(module,module_type) VALUES ('" + modulename + "' , '" + module_type + "')"
                print (sql)
                c.execute(sql)
                #c.execute("INSERT OR IGNORE INTO module_service(servicename, module, version)" .\
                #          "VALUES ('" + servicename + "' , '" + modulename + "' , '" + moduleversion + "')") 
                sql = "INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('" + servicename + "' , '" + modulename + "' , '" + moduleversion + "')"
                print (sql)
                c.execute(sql)
                
                
conn.commit()
conn.close()
# Out:
# ['arc1', 'infrastructure', 'allinea', '4.2.2-39422']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('allinea' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'allinea' , '4.2.2-39422')
# ['arc1', 'infrastructure', 'lmutil', '11.12.1.0v6']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('lmutil' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'lmutil' , '11.12.1.0v6')
# ['arc1', 'infrastructure', 'ant', '1.8.0']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ant' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ant' , '1.8.0')
# ['arc1', 'infrastructure', 'maven', '3.0.3']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('maven' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'maven' , '3.0.3')
# ['arc1', 'infrastructure', 'autoconf', '2.68']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('autoconf' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'autoconf' , '2.68')
# ['arc1', 'infrastructure', 'mercurial', '1.9.2']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mercurial' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mercurial' , '1.9.2')
# ['arc1', 'infrastructure', 'automake', '1.13.2']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('automake' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'automake' , '1.13.2')
# ['arc1', 'infrastructure', 'mercurial', '3.7.2']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mercurial' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mercurial' , '3.7.2')
# ['arc1', 'infrastructure', 'bit', '32']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('bit' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'bit' , '32')
# ['arc1', 'infrastructure', 'mpe2', '1.3.0']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mpe2' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mpe2' , '1.3.0')
# ['arc1', 'infrastructure', 'bit', '64']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('bit' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'bit' , '64')
# ['arc1', 'infrastructure', 'mvapich', '1.2rc1']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mvapich' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mvapich' , '1.2rc1')
# ['arc1', 'infrastructure', 'charm', '6.2.2-namd']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('charm' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'charm' , '6.2.2-namd')
# ['arc1', 'infrastructure', 'mvapich2', '1.4(default)']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mvapich2' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mvapich2' , '1.4(default)')
# ['arc1', 'infrastructure', 'charm', '6.3.2-namd']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('charm' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'charm' , '6.3.2-namd')
# ['arc1', 'infrastructure', 'nvidia', '280.13']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('nvidia' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'nvidia' , '280.13')
# ['arc1', 'infrastructure', 'cmake', '2.8.11.2']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('cmake' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'cmake' , '2.8.11.2')
# ['arc1', 'infrastructure', 'openmpi', '1.2.9']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('openmpi' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'openmpi' , '1.2.9')
# ['arc1', 'infrastructure', 'cmake', '2.8.2']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('cmake' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'cmake' , '2.8.2')
# ['arc1', 'infrastructure', 'openmpi', '1.4(default)']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('openmpi' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'openmpi' , '1.4(default)')
# ['arc1', 'infrastructure', 'cmake', '3.2.3']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('cmake' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'cmake' , '3.2.3')
# ['arc1', 'infrastructure', 'openmpi', '1.5.3']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('openmpi' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'openmpi' , '1.5.3')
# ['arc1', 'infrastructure', 'darcs', '2.5.2']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('darcs' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'darcs' , '2.5.2')
# ['arc1', 'infrastructure', 'openmpi', '1.6.5']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('openmpi' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'openmpi' , '1.6.5')
# ['arc1', 'infrastructure', 'doxygen', '1.8.8']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('doxygen' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'doxygen' , '1.8.8')
# ['arc1', 'infrastructure', 'sge']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('sge' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'sge' , '')
# ['arc1', 'infrastructure', 'flex', '2.5.39']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('flex' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'flex' , '2.5.39')
# ['arc1', 'infrastructure', 'sgedev']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('sgedev' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'sgedev' , '')
# ['arc1', 'infrastructure', 'git', '1.7.3.1']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('git' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'git' , '1.7.3.1')
# ['arc1', 'infrastructure', 'srb', '3.3.1']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('srb' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'srb' , '3.3.1')
# ['arc1', 'infrastructure', 'globus', '5.0.4']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('globus' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'globus' , '5.0.4')
# ['arc1', 'infrastructure', 'subversion', '1.6.15(default)']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('subversion' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'subversion' , '1.6.15(default)')
# ['arc1', 'infrastructure', 'intelmpi', '4.1.0.024(default)']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('intelmpi' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'intelmpi' , '4.1.0.024(default)')
# ['arc1', 'infrastructure', 'subversion', '1.6.9']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('subversion' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'subversion' , '1.6.9')
# ['arc1', 'infrastructure', 'intelmpi', '4.1.1.036']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('intelmpi' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'intelmpi' , '4.1.1.036')
# ['arc1', 'infrastructure', 'system']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('system' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'system' , '')
# ['arc1', 'infrastructure', 'intelmpi', '5.1.0.038']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('intelmpi' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'intelmpi' , '5.1.0.038')
# ['arc1', 'infrastructure', 'test']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('test' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'test' , '')
# ['arc1', 'infrastructure', 'libtool', '2.4.2']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('libtool' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'libtool' , '2.4.2')
# ['arc1', 'infrastructure', 'user']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('user' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'user' , '')
# ['arc1', 'infrastructure', 'licenses']
# infrastructure
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('licenses' , 'infrastructure')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'licenses' , '')
# ['arc1', 'compilers', 'epd', '7.3-1']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('epd' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'epd' , '7.3-1')
# ['arc1', 'compilers', 'intel', '15.0.0']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('intel' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'intel' , '15.0.0')
# ['arc1', 'compilers', 'pgi', '13.6']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('pgi' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'pgi' , '13.6')
# ['arc1', 'compilers', 'gnu', '4.2.3']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gnu' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gnu' , '4.2.3')
# ['arc1', 'compilers', 'intel', '16.0.2']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('intel' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'intel' , '16.0.2')
# ['arc1', 'compilers', 'python', '2.6.5']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python' , '2.6.5')
# ['arc1', 'compilers', 'gnu', '4.4.5']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gnu' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gnu' , '4.4.5')
# ['arc1', 'compilers', 'intel', '2011.2.137']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('intel' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'intel' , '2011.2.137')
# ['arc1', 'compilers', 'python', '2.7.2']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python' , '2.7.2')
# ['arc1', 'compilers', 'gnu', '4.7.1']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gnu' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gnu' , '4.7.1')
# ['arc1', 'compilers', 'java', '1.6.0_17']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('java' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'java' , '1.6.0_17')
# ['arc1', 'compilers', 'python', '2.7.6']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python' , '2.7.6')
# ['arc1', 'compilers', 'gnu', '4.8.1']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gnu' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gnu' , '4.8.1')
# ['arc1', 'compilers', 'java', '7u45']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('java' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'java' , '7u45')
# ['arc1', 'compilers', 'python', '3.1.2(default)']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python' , '3.1.2(default)')
# ['arc1', 'compilers', 'gnu', '5.3.0']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gnu' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gnu' , '5.3.0')
# ['arc1', 'compilers', 'mono', '2.8.1']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mono' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mono' , '2.8.1')
# ['arc1', 'compilers', 'python', '3.3.6']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python' , '3.3.6')
# ['arc1', 'compilers', 'gnu', 'native(default)']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gnu' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gnu' , 'native(default)')
# ['arc1', 'compilers', 'perl', 'native']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('perl' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'perl' , 'native')
# ['arc1', 'compilers', 'python', 'native']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python' , 'native')
# ['arc1', 'compilers', 'intel', '11.1.059(default)']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('intel' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'intel' , '11.1.059(default)')
# ['arc1', 'compilers', 'pgi', '10.0(default)']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('pgi' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'pgi' , '10.0(default)')
# ['arc1', 'compilers', 'tcl', '8.3.5']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('tcl' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'tcl' , '8.3.5')
# ['arc1', 'compilers', 'intel', '13.1.3.192']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('intel' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'intel' , '13.1.3.192')
# ['arc1', 'compilers', 'pgi', '11.3']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('pgi' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'pgi' , '11.3')
# ['arc1', 'compilers', 'yasm', '1.2.0']
# compilers
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('yasm' , 'compilers')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'yasm' , '1.2.0')
# ['arc1', 'libraries', 'acml', '4.4.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('acml' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'acml' , '4.4.0')
# ['arc1', 'libraries', 'mkl', '11.0u5']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mkl' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mkl' , '11.0u5')
# ['arc1', 'libraries', 'antlr', '2.7.7']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('antlr' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'antlr' , '2.7.7')
# ['arc1', 'libraries', 'mkl', '11.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mkl' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mkl' , '11.2')
# ['arc1', 'libraries', 'armadillo', '3.810.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('armadillo' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'armadillo' , '3.810.2')
# ['arc1', 'libraries', 'netcdf', '3.6.3(default)']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('netcdf' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'netcdf' , '3.6.3(default)')
# ['arc1', 'libraries', 'atlas', '3.10.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('atlas' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'atlas' , '3.10.1')
# ['arc1', 'libraries', 'netcdf', '4.3.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('netcdf' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'netcdf' , '4.3.0')
# ['arc1', 'libraries', 'atlas', '3.8.3']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('atlas' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'atlas' , '3.8.3')
# ['arc1', 'libraries', 'netlib', '3.3.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('netlib' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'netlib' , '3.3.0')
# ['arc1', 'libraries', 'boost', '1.53.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('boost' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'boost' , '1.53.0')
# ['arc1', 'libraries', 'ompP', '0.8.5']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ompP' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ompP' , '0.8.5')
# ['arc1', 'libraries', 'cube', '4.2.3']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('cube' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'cube' , '4.2.3')
# ['arc1', 'libraries', 'opencv', '2.2.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('opencv' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'opencv' , '2.2.0')
# ['arc1', 'libraries', 'cube', '4.3.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('cube' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'cube' , '4.3.1')
# ['arc1', 'libraries', 'opencv', '2.4.6.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('opencv' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'opencv' , '2.4.6.1')
# ['arc1', 'libraries', 'darshan', '2.3.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('darshan' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'darshan' , '2.3.0')
# ['arc1', 'libraries', 'openjpeg', '1.5.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('openjpeg' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'openjpeg' , '1.5.1')
# ['arc1', 'libraries', 'eigen', '3.2.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('eigen' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'eigen' , '3.2.2')
# ['arc1', 'libraries', 'openslide', '3.2.6']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('openslide' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'openslide' , '3.2.6')
# ['arc1', 'libraries', 'ffmpeg', '0.6.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ffmpeg' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ffmpeg' , '0.6.2')
# ['arc1', 'libraries', 'otf2', '1.2.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('otf2' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'otf2' , '1.2.1')
# ['arc1', 'libraries', 'ffmpeg', '1.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ffmpeg' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ffmpeg' , '1.2')
# ['arc1', 'libraries', 'otf2', '1.5.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('otf2' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'otf2' , '1.5.1')
# ['arc1', 'libraries', 'ffmpeg', '2.0.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ffmpeg' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ffmpeg' , '2.0.2')
# ['arc1', 'libraries', 'papi', '5.4.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('papi' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'papi' , '5.4.0')
# ['arc1', 'libraries', 'fftw', '2.1.5']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('fftw' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'fftw' , '2.1.5')
# ['arc1', 'libraries', 'pdt', '3.20']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('pdt' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'pdt' , '3.20')
# ['arc1', 'libraries', 'fftw', '3.2.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('fftw' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'fftw' , '3.2.2')
# ['arc1', 'libraries', 'perl-libs', '1.0.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('perl-libs' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'perl-libs' , '1.0.0')
# ['arc1', 'libraries', 'fftw', '3.3.3']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('fftw' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'fftw' , '3.3.3')
# ['arc1', 'libraries', 'petsc', '3.1-p8']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('petsc' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'petsc' , '3.1-p8')
# ['arc1', 'libraries', 'freetype', '2.4.12']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('freetype' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'freetype' , '2.4.12')
# ['arc1', 'libraries', 'pgplot', '5.2.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('pgplot' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'pgplot' , '5.2.2')
# ['arc1', 'libraries', 'gdal', '1.11.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gdal' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gdal' , '1.11.0')
# ['arc1', 'libraries', 'proj', '4.8.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('proj' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'proj' , '4.8.0')
# ['arc1', 'libraries', 'geos', '3.4.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('geos' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'geos' , '3.4.2')
# ['arc1', 'libraries', 'python-libs', '1.0.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python-libs' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python-libs' , '1.0.0')
# ['arc1', 'libraries', 'graphviz', '2.28.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('graphviz' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'graphviz' , '2.28.0')
# ['arc1', 'libraries', 'python-libs', '1.0.1(default)']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python-libs' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python-libs' , '1.0.1(default)')
# ['arc1', 'libraries', 'gsl', '1.14']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gsl' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gsl' , '1.14')
# ['arc1', 'libraries', 'python-libs', '1.0.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python-libs' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python-libs' , '1.0.2')
# ['arc1', 'libraries', 'gsl', '1.15']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gsl' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gsl' , '1.15')
# ['arc1', 'libraries', 'python-libs', '1.0.3']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python-libs' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python-libs' , '1.0.3')
# ['arc1', 'libraries', 'harminv', '1.3.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('harminv' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'harminv' , '1.3.1')
# ['arc1', 'libraries', 'python-libs', '2.4.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('python-libs' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'python-libs' , '2.4.0')
# ['arc1', 'libraries', 'hdf-java', '2.9']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('hdf-java' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'hdf-java' , '2.9')
# ['arc1', 'libraries', 'qt', '4.8.6']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('qt' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'qt' , '4.8.6')
# ['arc1', 'libraries', 'hdf5', '1.8.11']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('hdf5' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'hdf5' , '1.8.11')
# ['arc1', 'libraries', 'root', '5.34.05']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('root' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'root' , '5.34.05')
# ['arc1', 'libraries', 'hdf5', '1.8.12']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('hdf5' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'hdf5' , '1.8.12')
# ['arc1', 'libraries', 'root', '5.34.23']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('root' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'root' , '5.34.23')
# ['arc1', 'libraries', 'hdf5', '1.8.5p1(default)']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('hdf5' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'hdf5' , '1.8.5p1(default)')
# ['arc1', 'libraries', 'scorep', '1.3']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('scorep' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'scorep' , '1.3')
# ['arc1', 'libraries', 'hypre', '2.7.0b']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('hypre' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'hypre' , '2.7.0b')
# ['arc1', 'libraries', 'scorep', '1.4.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('scorep' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'scorep' , '1.4.1')
# ['arc1', 'libraries', 'hypre', '2.9.0b']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('hypre' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'hypre' , '2.9.0b')
# ['arc1', 'libraries', 'silo', '4.10.2']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('silo' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'silo' , '4.10.2')
# ['arc1', 'libraries', 'itac', '8.0.3.007']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('itac' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'itac' , '8.0.3.007')
# ['arc1', 'libraries', 'suitesparse', '3.6.0']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('suitesparse' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'suitesparse' , '3.6.0')
# ['arc1', 'libraries', 'jasper', '1.900.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('jasper' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'jasper' , '1.900.1')
# ['arc1', 'libraries', 'suitesparse', '4.2.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('suitesparse' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'suitesparse' , '4.2.1')
# ['arc1', 'libraries', 'libctl', '3.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('libctl' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'libctl' , '3.1')
# ['arc1', 'libraries', 'tau', '2.24']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('tau' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'tau' , '2.24')
# ['arc1', 'libraries', 'libunwind', '1.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('libunwind' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'libunwind' , '1.1')
# ['arc1', 'libraries', 'udunits', '2.2.17']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('udunits' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'udunits' , '2.2.17')
# ['arc1', 'libraries', 'lzo', '2.04']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('lzo' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'lzo' , '2.04')
# ['arc1', 'libraries', 'vtk', '5.6.1']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('vtk' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'vtk' , '5.6.1')
# ['arc1', 'libraries', 'mkl', '10.3u2(default)']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mkl' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mkl' , '10.3u2(default)')
# ['arc1', 'libraries', 'wxgtk', '2.8.11']
# libraries
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('wxgtk' , 'libraries')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'wxgtk' , '2.8.11')
# ['arc1', 'applications', 'FusionMap', '1.42']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('FusionMap' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'FusionMap' , '1.42')
# ['arc1', 'applications', 'comsol', '4.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('comsol' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'comsol' , '4.1')
# ['arc1', 'applications', 'matlab', 'R2012a']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('matlab' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'matlab' , 'R2012a')
# ['arc1', 'applications', 'R', '2.10.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('R' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'R' , '2.10.1')
# ['arc1', 'applications', 'comsol', '4.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('comsol' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'comsol' , '4.2')
# ['arc1', 'applications', 'meep', '1.1.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('meep' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'meep' , '1.1.1')
# ['arc1', 'applications', 'R', '2.13.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('R' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'R' , '2.13.0')
# ['arc1', 'applications', 'comsol', '4.2a']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('comsol' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'comsol' , '4.2a')
# ['arc1', 'applications', 'mesmer', '4.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mesmer' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mesmer' , '4.0')
# ['arc1', 'applications', 'R', '2.15.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('R' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'R' , '2.15.0')
# ['arc1', 'applications', 'comsol', '4.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('comsol' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'comsol' , '4.3')
# ['arc1', 'applications', 'molpro', '2006.1.148']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('molpro' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'molpro' , '2006.1.148')
# ['arc1', 'applications', 'R', '2.15.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('R' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'R' , '2.15.3')
# ['arc1', 'applications', 'comsol', '4.3a']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('comsol' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'comsol' , '4.3a')
# ['arc1', 'applications', 'molpro', '2010.1.23(default)']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('molpro' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'molpro' , '2010.1.23(default)')
# ['arc1', 'applications', 'R', '3.0.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('R' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'R' , '3.0.2')
# ['arc1', 'applications', 'comsol', '4.3b']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('comsol' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'comsol' , '4.3b')
# ['arc1', 'applications', 'molpro', '2010.1.24']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('molpro' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'molpro' , '2010.1.24')
# ['arc1', 'applications', 'R', '3.1.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('R' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'R' , '3.1.0')
# ['arc1', 'applications', 'cufflinks', '1.3.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('cufflinks' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'cufflinks' , '1.3.0')
# ['arc1', 'applications', 'mpb', '1.4.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('mpb' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'mpb' , '1.4.2')
# ['arc1', 'applications', 'R', '3.2.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('R' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'R' , '3.2.0')
# ['arc1', 'applications', 'cufflinks', '2.2.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('cufflinks' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'cufflinks' , '2.2.1')
# ['arc1', 'applications', 'namd', '2.7b4']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('namd' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'namd' , '2.7b4')
# ['arc1', 'applications', 'R', '3.2.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('R' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'R' , '3.2.2')
# ['arc1', 'applications', 'desmond', '2.2.9.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('desmond' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'desmond' , '2.2.9.1')
# ['arc1', 'applications', 'namd', '2.8']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('namd' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'namd' , '2.8')
# ['arc1', 'applications', 'abaqus', '6.10']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('abaqus' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'abaqus' , '6.10')
# ['arc1', 'applications', 'dl_poly', '2.20']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('dl_poly' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'dl_poly' , '2.20')
# ['arc1', 'applications', 'namd', '2.9']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('namd' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'namd' , '2.9')
# ['arc1', 'applications', 'abaqus', '6.12']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('abaqus' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'abaqus' , '6.12')
# ['arc1', 'applications', 'dl_poly', '4.05']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('dl_poly' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'dl_poly' , '4.05')
# ['arc1', 'applications', 'nbo', '6']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('nbo' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'nbo' , '6')
# ['arc1', 'applications', 'abaqus', '6.9EF']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('abaqus' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'abaqus' , '6.9EF')
# ['arc1', 'applications', 'ehits', '12.0(default)']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ehits' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ehits' , '12.0(default)')
# ['arc1', 'applications', 'ncl', '6.0.0-beta']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ncl' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ncl' , '6.0.0-beta')
# ['arc1', 'applications', 'adams', '2013.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('adams' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'adams' , '2013.2')
# ['arc1', 'applications', 'ehits', '13.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ehits' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ehits' , '13.0')
# ['arc1', 'applications', 'nco', '4.0.8(default)']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('nco' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'nco' , '4.0.8(default)')
# ['arc1', 'applications', 'aimpro', '2.3.11b2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('aimpro' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'aimpro' , '2.3.11b2')
# ['arc1', 'applications', 'ehits', '14.0.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ehits' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ehits' , '14.0.3')
# ['arc1', 'applications', 'nco', '4.3.7']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('nco' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'nco' , '4.3.7')
# ['arc1', 'applications', 'amber', '10(default)']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('amber' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'amber' , '10(default)')
# ['arc1', 'applications', 'ehits', '2009.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ehits' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ehits' , '2009.1')
# ['arc1', 'applications', 'ncview', '1.93g']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ncview' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ncview' , '1.93g')
# ['arc1', 'applications', 'amber', '12']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('amber' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'amber' , '12')
# ['arc1', 'applications', 'espresso', '4.1.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('espresso' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'espresso' , '4.1.2')
# ['arc1', 'applications', 'onetep', '3.0.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('onetep' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'onetep' , '3.0.0')
# ['arc1', 'applications', 'amber', '9']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('amber' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'amber' , '9')
# ['arc1', 'applications', 'ferret', '6.8.5']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ferret' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ferret' , '6.8.5')
# ['arc1', 'applications', 'opendx', '4.4.4']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('opendx' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'opendx' , '4.4.4')
# ['arc1', 'applications', 'ansys', '12.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ansys' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ansys' , '12.0')
# ['arc1', 'applications', 'gaussian', 'G03.D02']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gaussian' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gaussian' , 'G03.D02')
# ['arc1', 'applications', 'openeye', '3.0.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('openeye' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'openeye' , '3.0.1')
# ['arc1', 'applications', 'ansys', '12.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ansys' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ansys' , '12.1')
# ['arc1', 'applications', 'gaussian', 'G09']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gaussian' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gaussian' , 'G09')
# ['arc1', 'applications', 'openfoam', '1.7.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('openfoam' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'openfoam' , '1.7.1')
# ['arc1', 'applications', 'ansys', '13.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ansys' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ansys' , '13.0')
# ['arc1', 'applications', 'gaussian', 'G09.D01']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gaussian' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gaussian' , 'G09.D01')
# ['arc1', 'applications', 'openfoam', '2.1.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('openfoam' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'openfoam' , '2.1.1')
# ['arc1', 'applications', 'ansys', '13.0sp2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ansys' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ansys' , '13.0sp2')
# ['arc1', 'applications', 'gmt', '4.5.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gmt' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gmt' , '4.5.2')
# ['arc1', 'applications', 'paraview', '3.8.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('paraview' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'paraview' , '3.8.1')
# ['arc1', 'applications', 'ansys', '14.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ansys' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ansys' , '14.0')
# ['arc1', 'applications', 'gnuplot', '4.2.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gnuplot' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gnuplot' , '4.2.3')
# ['arc1', 'applications', 'pari', '2.5.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('pari' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'pari' , '2.5.0')
# ['arc1', 'applications', 'ansys', '14.5.7']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ansys' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ansys' , '14.5.7')
# ['arc1', 'applications', 'grace', '5.1.22']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('grace' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'grace' , '5.1.22')
# ['arc1', 'applications', 'relion', '1.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('relion' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'relion' , '1.2')
# ['arc1', 'applications', 'ansys', '16.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ansys' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ansys' , '16.2')
# ['arc1', 'applications', 'gromacs', '4.5.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gromacs' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gromacs' , '4.5.1')
# ['arc1', 'applications', 'samtools', '0.1.18']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('samtools' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'samtools' , '0.1.18')
# ['arc1', 'applications', 'ansysem', '15.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ansysem' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ansysem' , '15.0')
# ['arc1', 'applications', 'gromacs', '4.5.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gromacs' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gromacs' , '4.5.3')
# ['arc1', 'applications', 'sas', '9.2.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('sas' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'sas' , '9.2.2')
# ['arc1', 'applications', 'aten', '1.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('aten' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'aten' , '1.3')
# ['arc1', 'applications', 'gromacs', '4.5.5']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gromacs' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gromacs' , '4.5.5')
# ['arc1', 'applications', 'schrodinger', '2014-3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('schrodinger' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'schrodinger' , '2014-3')
# ['arc1', 'applications', 'bfast', '0.7.0a']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('bfast' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'bfast' , '0.7.0a')
# ['arc1', 'applications', 'gromacs', '4.6.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gromacs' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gromacs' , '4.6.3')
# ['arc1', 'applications', 'schrodinger', '2016-3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('schrodinger' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'schrodinger' , '2016-3')
# ['arc1', 'applications', 'blast', '2.2.25']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('blast' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'blast' , '2.2.25')
# ['arc1', 'applications', 'gulp', '3.4']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('gulp' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'gulp' , '3.4')
# ['arc1', 'applications', 'stata', '12']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('stata' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'stata' , '12')
# ['arc1', 'applications', 'bowtie', '0.12.7']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('bowtie' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'bowtie' , '0.12.7')
# ['arc1', 'applications', 'h5utils', '1.12.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('h5utils' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'h5utils' , '1.12.1')
# ['arc1', 'applications', 'stata', '13']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('stata' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'stata' , '13')
# ['arc1', 'applications', 'bwa', '0.6.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('bwa' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'bwa' , '0.6.1')
# ['arc1', 'applications', 'hyperworks', '10(default)']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('hyperworks' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'hyperworks' , '10(default)')
# ['arc1', 'applications', 'stata', '13.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('stata' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'stata' , '13.1')
# ['arc1', 'applications', 'bwa', '0.7.6a']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('bwa' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'bwa' , '0.7.6a')
# ['arc1', 'applications', 'idl', '7.0']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('idl' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'idl' , '7.0')
# ['arc1', 'applications', 'tophat', '1.3.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('tophat' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'tophat' , '1.3.3')
# ['arc1', 'applications', 'castep', '4.4.6']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('castep' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'castep' , '4.4.6')
# ['arc1', 'applications', 'iris-explorer', '5.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('iris-explorer' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'iris-explorer' , '5.2')
# ['arc1', 'applications', 'visit', '2.9.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('visit' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'visit' , '2.9.2')
# ['arc1', 'applications', 'castep', '5.0.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('castep' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'castep' , '5.0.1')
# ['arc1', 'applications', 'joint-snv-mix', '0.7.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('joint-snv-mix' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'joint-snv-mix' , '0.7.3')
# ['arc1', 'applications', 'vmd', '1.8.7']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('vmd' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'vmd' , '1.8.7')
# ['arc1', 'applications', 'castep', '5.0.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('castep' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'castep' , '5.0.2')
# ['arc1', 'applications', 'ls-dyna', '971r4.2.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('ls-dyna' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'ls-dyna' , '971r4.2.1')
# ['arc1', 'applications', 'weka', '3.6.7']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('weka' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'weka' , '3.6.7')
# ['arc1', 'applications', 'castep', '5.5']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('castep' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'castep' , '5.5')
# ['arc1', 'applications', 'macs', '1.3.7']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('macs' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'macs' , '1.3.7')
# ['arc1', 'applications', 'wien2k', '09.2']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('wien2k' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'wien2k' , '09.2')
# ['arc1', 'applications', 'castep', '5.5.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('castep' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'castep' , '5.5.1')
# ['arc1', 'applications', 'macs', '1.4.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('macs' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'macs' , '1.4.1')
# ['arc1', 'applications', 'wien2k', '11.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('wien2k' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'wien2k' , '11.1')
# ['arc1', 'applications', 'castep', '6.0p3(default)']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('castep' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'castep' , '6.0p3(default)')
# ['arc1', 'applications', 'materialsstudio', '5.5.3']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('materialsstudio' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'materialsstudio' , '5.5.3')
# ['arc1', 'applications', 'xmipp', '2.4']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('xmipp' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'xmipp' , '2.4')
# ['arc1', 'applications', 'castep', '6.1.1']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('castep' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'castep' , '6.1.1')
# ['arc1', 'applications', 'matlab', '7.9(default)']
# applications
# INSERT OR IGNORE INTO module(module,module_type) VALUES ('matlab' , 'applications')
# INSERT OR IGNORE INTO module_service(servicename, module, version) VALUES ('arc1' , 'matlab' , '7.9(default)')

# %%
dbfilename = 'mods.sqlite'
conn = sqlite3.connect(dbfilename)
c = conn.cursor()

sql = "SELECT module.module, module_service.version FROM module, module_service WHERE module_servicename = 'arc1' AND module.module_type= 'applications'"
